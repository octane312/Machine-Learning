# %% [markdown]
# <a href="https://colab.research.google.com/github/octane312/Machine-Learning/blob/main/Decision_Tree_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DECISION TREE CLASSIFIER**

# %% [markdown]
# ## **IMPORTING MODEL**

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## **LOAD DATASET**

# %%
data=load_iris()
X,Y=data.data,data.target
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %% [markdown]
# ## **SPLITTING DATASET**

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=50)

# %% [markdown]
# ## **FITTING MODEL**

# %%
model=DecisionTreeClassifier(criterion='entropy',random_state=50)
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=50)

# %% [markdown]
# ## **PREDICTING USING MODEL**

# %%
Y_pred=model.predict(X_test)

# %% [markdown]
# ## **EVALUATING MODEL**

# %%
accuracy=accuracy_score(Y_test,Y_pred)
accuracy
# Out:
# 0.9666666666666667

# %% [markdown]
# ## **DATA VISUALIZATION**

# %%
plt.figure(figsize=(12,8))
plot_tree(model,filled=True,feature_names=data.feature_names,class_names=data.target_names)
plt.show()
